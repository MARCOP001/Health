# %%
import pandas as pd

# %%
dataset = pd.read_csv("Obesity.csv")
display(dataset.head())
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
print(dataset.dtypes)
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
print(f"\n Il dataset contiene {dataset.shape[0]} osservazioni e {dataset.shape[1]} variabili.\n")
# Out:
#  Il dataset contiene 2114 osservazioni e 17 variabili.

# %%
print(f"\n Valori Mancanti per ogni variabile\n")
missing_values = dataset.isna().sum()
missing_values
# Out:
#  Valori Mancanti per ogni variabile
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              5
# MTRANS                            0
# NObeyesdad                        1
# dtype: int64

# %%
missing_values_percent = (missing_values/len(dataset))*100
missing_values_table = pd.DataFrame({"Valori Mancanti": missing_values, "% del totale": missing_values_percent})
display(missing_values_table[missing_values_table["Valori Mancanti"] > 0])

print(f"\n Valori mancanti Consumo Alcolici\n")
dataset[dataset["CALC"].isna()]
# Out:
#             Valori Mancanti  % del totale
# CALC                      5      0.236518
# NObeyesdad                1      0.047304
#  Valori mancanti Consumo Alcolici
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 13     Male  41.0    1.80    99.0                             no  yes   2.0
# 94   Female  24.0    1.60    48.0                             no  yes   3.0
# 162  Female  21.0    1.63    60.0                            yes  yes   3.0
# 278  Female  32.0    1.57    57.0                            yes  yes   3.0
# 463    Male  17.0    1.80    68.0                            yes   no   2.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE CALC                 MTRANS  \
# 13   3.0  Sometimes    no   2.0  no  2.0  1.0  NaN             Automobile
# 94   3.0  Sometimes    no   2.0  no  2.0  0.0  NaN  Public_Transportation
# 162  3.0     Always   yes   2.0  no  2.0  0.0  NaN  Public_Transportation
# 278  3.0  Sometimes    no   2.0  no  0.0  0.0  NaN             Automobile
# 463  3.0  Sometimes    no   1.0  no  2.0  1.0  NaN  Public_Transportation
#
#          NObeyesdad
# 13   Obesity_Type_I
# 94    Normal_Weight
# 162   Normal_Weight
# 278   Normal_Weight
# 463   Normal_Weight

# %%
print(f"\n Valori mancanti livello Obesità\n")
dataset[dataset["NObeyesdad"].isna()]
# Out:
#  Valori mancanti livello Obesità
#      Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 376  Female  36.0    1.58    60.0                            yes   no   3.0
#
#      NCP       CAEC SMOKE  CH2O SCC  FAF  TUE       CALC      MTRANS  \
# 376  3.0  Sometimes    no   1.0  no  2.0  0.0  Sometimes  Automobile
#
#     NObeyesdad
# 376        NaN

# %%
print(f"\n Gestione valori mancanti\n")
#da scegliere tra due strategie: rimozione (dataset.dropna()) o imputazione (dataset.fillna(value)) 
#nel primo caso eliminiamo tutte le righe che presentano dei valori mancanti (adatto quando ci sono pochi valori mancanti)
#nel secondo caso sostituiamo i valori mancanti con un valore (es: media, mediana, ecc...) (adatto quando non si vogliono perdere dati ed è possibile stimare il valori mancanti)
dataset_clean = dataset.dropna()
# Out:
#  Gestione valori mancanti
